# %% [markdown]
# # Printing Emojis
# ---

# %%
print("\U0001F607")
# Out:
# 😇

# %%
print("\U0001F92D")
# Out:
# 🤭

# %%
print("\U0001F600")
# Out:
# 😀

# %%
print("\U0001F609")
# Out:
# 😉

# %%
print("\U0001F929")
# Out:
# 🤩

# %%
print("\U0001F642")
# Out:
# 🙂

# %%
print("\U0001F613")
# Out:
# 😓

# %% [markdown]
#  ![Emojis.JPG](attachment:Emojis.JPG)
# <b> From the list of unicodes, replace “+” with “000”. For example – “U+1F600” will become “U0001F600” and prefix the unicode with   “\” and print it. </b>

# %%
print("❤")
# Out:
# ❤

# %%
print("\U0001F606")
# Out:
# 😆

# %%
print("\U0001F602")
# Out:
# 😂

# %%
print("\U0001F634")
# Out:
# 😴

# %%
print("\U0001F644")
# Out:
# 🙄

# %%
print("\U0001F600")
# Out:
# 😀
